# %% [markdown]
# # COMP5329: Assignment 1 Code

# %% [markdown]
# ### *Dongdong Zhang (470161133), Quan Chen (470199228), Rui Wang (470208162)*
# ______________________________________________________________________________

# %% [markdown]
# ## 1. Initial setup and data load
# ### 1.1 Libraries and configuration

# %%
# =================
# IMPORT LIBRARIES
# =================
import h5py
import numpy as np
import pandas as pd
import matplotlib.pyplot as pl
import seaborn as sns
from time import time
# Out:
# /usr/local/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ## 2. Load and Preprocessing Data
# ### 2.1 Load Raw Data

# %%
# Read all data and load into files
with h5py.File('train_128.h5', 'r') as H:
    data = np.copy(H['data'])

with h5py.File('train_label.h5', 'r') as H:
    label = np.copy(H['label'])

with h5py.File('test_128.h5', 'r') as H:
    test_data = np.copy(H['data'])

print('train_128.h5: ' + str(data.shape))
print('train_label.h5: ' + str(label.shape))
print('test_128.h5: ' + str(test_data.shape))
print("\n----------------------")
# Out:
# train_128.h5: (60000, 128)
# train_label.h5: (60000,)
# test_128.h5: (10000, 128)
#
# ----------------------

# %% [markdown]
# The train data label distributed extremely uniformity as follow

# %%
# --------------------------------------------
# VISUALISE LABELS AND FREQUENCIES (BAR CHART)
# --------------------------------------------
pl.figure(figsize=(9,9))
sns.set(style='darkgrid')
ax_label = sns.countplot(y = label, palette="RdBu")
ax_label.set(ylabel = 'Label', xlabel = 'Count')
pl.show()

# %% [markdown]
# ### 2.2 Data Preprocessing
# We transform the data to array type, then normalize the input data by $x_i=\frac{x_i-\mu}{\delta}$, and transform the label data to one-hot label

# %%
# Transform data to array
input_data = np.array(data, dtype=float)
test_data = np.array(test_data, dtype=float)

# Normalization Data (x-mu)/delta
input_data = (input_data - input_data.mean(axis=0, keepdims=True)) / input_data.std(axis=0, keepdims=True)
test_data = (test_data - test_data.mean(axis=0, keepdims=True)) / test_data.std(axis=0, keepdims=True)

# Transform to one-hot label
label_data = np.array(np.eye(10)[label.reshape(-1)], dtype=float)

# %% [markdown]
# ## 3. Main Classes
# ### 3.1 Activation Class
# We define tanh, logistic, relu activative function.

# %%
class Activation(object):
    def __tanh(self, x):
        return np.tanh(x)

    def __tanh_deriv(self, a):
        # a = np.tanh(x)
        return 1.0 - a**2

    def __logistic(self, x):
        return 1.0 / (1.0 + np.exp(-x))

    def __logistic_derivative(self, a):
        # a = logistic(x)
        return a * (1 - a)

    # define relu activation and relu derivative
    def __relu(self, x):
        index = (x < 0)
        x[index] = 0
        return x

    def __relu_deriv(self, a):
        index1 = (a>=0)
        index0 = np.logical_not(index1)
        a[index1]=1
        a[index0]=0
        return a

    # default activation is relu
    def __init__(self, activation='relu'):
        if activation == 'logistic':
            self.f = self.__logistic
            self.f_deriv = self.__logistic_derivative
        elif activation == 'tanh':
            self.f = self.__tanh
            self.f_deriv = self.__tanh_deriv

        # choose relu
        elif activation == 'relu':
            self.f = self.__relu
            self.f_deriv = self.__relu_deriv

# %% [markdown]
# ### 3.2 Input and output layer classes
# Due to some module shouldn't in input and output layers, so we split input&output layer class and hidden layer class.
# This class with MLP class defines momentum, weight normalization, batch normalization module.

# %%
class InputOuput_Layer(object):
    def __init__(self, n_in, n_out, W=None, b=None, activation='relu', weight_norm=None):
        self.input = None
        self.activation = Activation(activation).f
        self.activation_deriv = Activation(activation).f_deriv

        # so use He initialization
        self.W = np.random.randn(n_in, n_out) * np.sqrt(2.0 / n_in)
        self.b = np.zeros(n_out,)
        self.n_in = n_in
        self.n_out = n_out

        # set whether implement weight normalization
        self.weight_norm = weight_norm
        self.grad_W = np.zeros(self.W.shape)
        self.grad_b = np.zeros(self.b.shape)

        # batch normalization init gamma and beta
        self.gamma_BN = np.ones((1, n_in))
        self.beta_BN = 0 #np.zeros(n_in,)
        self.grad_gamma_BN = np.ones(self.gamma_BN.shape)
        self.grad_beta_BN = 0 #np.zeros(self.beta_BN.shape)

        # momentum init v and b params
        self.v_w = np.zeros(self.W.shape)
        self.v_b = np.zeros(self.b.shape)
        # momentum with batch normalization init
        self.v_gamma_BN = np.zeros(self.gamma_BN.shape)
        self.v_beta_BN = 0

    def forward(self, input, BN=False, err_BN=0):
        # judge whether weight normalization and implement
        if self.weight_norm is True:
            self.W = self.W / (((self.W ** 2).sum(axis = 0, keepdims = True)) ** 0.5)
            self.W = np.nan_to_num(self.W)
        # implement forward function and judge whether use activation function
        lin_output = np.dot(input, self.W) + self.b
        self.output = (
            lin_output if self.activation is None
            else self.activation(lin_output)
        )
        self.input = input
        return self.output

    def forward_predict(self, input, BN=False, err_BN=1e-8):
        # only use it in predict data
        lin_output = np.dot(input, self.W) + self.b
        self.output = (
            lin_output if self.activation is None
            else self.activation(lin_output)
        )
        self.input = input
        return self.output

    def backward(self, delta):
        self.grad_W = np.atleast_2d(self.input).T.dot(np.atleast_2d(delta))
        self.grad_b = np.sum(delta)
        delta_ = delta.dot(self.W.T) * self.activation_deriv(self.input)
        # return delta_ for next layer
        return delta_
    
    
    # backward with batch normalization calculate grad_gamma and grad_beta
    # gamma = ∆J/∆y * X ; beta = ∆J/∆y ; ∆J/∆y = y - y_hat because  f_derivative=1
    # formula from: https://chrisyeh96.github.io/2017/08/28/deriving-batchnorm-backprop.html
    # https://arxiv.org/pdf/1502.03167.pdf
    def backward_BN(self, delta):
        self.grad_W = np.atleast_2d(self.input).T.dot(np.atleast_2d(delta))
        self.grad_b = np.sum(delta)
        delta_ = delta.dot(self.W.T) * self.activation_deriv(self.input)
        # return delta_ for next layer
        return delta_

# %% [markdown]
# ### 3.3 Hidden Layer Class
# It is hidden layer class, and with MLP class defines dropout, weight decay, batch normalization, momentum, weight normalization module.

# %%
class HiddenLayer(object):
    def __init__(self, n_in, n_out, W=None, b=None, activation='relu', weight_norm=False, 
                 dropout=False, keep_prob=0.5, weight_decay=False, weight_lambda=0.01):
        # initial stage
        self.input = None
        self.activation = Activation(activation).f
        self.activation_deriv = Activation(activation).f_deriv
        
        # we use He initialization
        self.W = np.random.randn(n_in, n_out) * np.sqrt(2.0 / n_in)
        self.b = np.zeros(n_out,)
        self.n_in = n_in
        self.n_out = n_out
        
        # set whether implement weight normalization
        self.weight_norm = weight_norm
        
        # set whether implement weight decay and init
        self.weight_decay = weight_decay
        self.weight_lambda = weight_lambda
        
        # set whether implement dropout
        self.dropout = dropout
        if dropout is True:
            print("Using dropout")
        self.keep_prob = keep_prob
        self.grad_W = np.zeros(self.W.shape)
        self.grad_b = np.zeros(self.b.shape)
        
        # batch normalization init gamma and beta
        self.gamma_BN = np.ones((1, n_in))
        self.beta_BN = 0 #np.zeros(n_in,)
        self.grad_gamma_BN = np.ones(self.gamma_BN.shape)
        self.grad_beta_BN = 0 #np.zeros(self.beta_BN.shape)
        self.BN_mean_total = []
        self.BN_var_total = []
        
        # momentum init v and b params
        self.v_w = np.zeros(self.W.shape)
        self.v_b = np.zeros(self.b.shape)
        # momentum with batch normalization init
        self.v_gamma_BN = np.zeros(self.gamma_BN.shape)
        self.v_beta_BN = 0

    def forward(self, input, BN=False, err_BN=1e-8):
        # judge the weight norm and implement
        if self.weight_norm is True:
            self.W = self.W / (((self.W ** 2).sum(axis = 0, keepdims = True)) ** 0.5)
            self.W = np.nan_to_num(self.W)
        # judge the dropout and implement
        if self.dropout is True:
            # set random probability matrix in every double layer
            prob = np.random.rand(input.shape[0], input.shape[1])
            prob = prob < self.keep_prob
            input = input * prob
        # judge whether weight decay and implement
        if self.weight_decay is True:
            self.W = self.W + self.weight_lambda * np.sum(self.W ** 2, axis=0) / 2
        # judge whether normalization and implement
        if BN is True:
            input_mean = input.mean(axis=0, keepdims=True)
            input_var = input.var(axis=0, keepdims=True)
            input = (input - input_mean) / np.sqrt(input_var + err_BN)
            input = input * self.gamma_BN + self.beta_BN
            self.BN_mean_total.append(input_mean)
            self.BN_var_total.append(input_var)
        # calculate this layer output
        lin_output = np.dot(input, self.W) + self.b
        self.output = (
            lin_output if self.activation is None
            else self.activation(lin_output)
        )
        self.input = input
        return self.output

    def forward_predict(self, input, BN=False, err_BN=1e-8):
        # judge whether batch normalization and implement it use average of all training batches mean and variances
        if BN is True:
            input_mean = np.mean(self.BN_mean_total)
            input_var = np.mean(self.BN_var_total)
            input = (input - input_mean) / np.sqrt(input_var + err_BN)
            input = input * self.gamma_BN + self.beta_BN
            # input = np.dot(input, self.gamma_BN) + self.beta_BN

        lin_output = np.dot(input, self.W) + self.b
        self.output = (
            lin_output if self.activation is None
            else self.activation(lin_output)
        )
        self.input = input
        return self.output

    # input is from previous layer, it is a_pre
    # delta is dz, delta_ is next layer's delta
    def backward(self, delta):
        self.grad_W = np.atleast_2d(self.input).T.dot(np.atleast_2d(delta))
        self.grad_b = np.sum(delta)
        delta_ = delta.dot(self.W.T) * self.activation_deriv(self.input)
        # return delta_ for next layer
        return delta_

    # backward with batch normalization calculate grad_gamma and grad_beta
    # gamma = ∆J/∆y * X ; beta = ∆J/∆y ; ∆J/∆y = y - y_hat because  f_derivative=1
    # formula from: https://chrisyeh96.github.io/2017/08/28/deriving-batchnorm-backprop.html
    # https://arxiv.org/pdf/1502.03167.pdf
    def backward_BN(self, delta):
        self.grad_W = np.atleast_2d(self.input).T.dot(np.atleast_2d(delta))
        self.grad_b = np.sum(delta)
    
        delta_ = delta.dot(self.W.T) * self.activation_deriv(self.input)
        
        self.grad_gamma_BN = np.mean(delta_, axis=0, keepdims=True) * self.gamma_BN
        self.grad_beta_BN = np.mean(delta_)
        
        delta__ = delta_ * self.gamma_BN
        # delta__ = np.nan_to_num(delta__)
        # return delta_ for next layer
        return delta__

# %% [markdown]
# ### 3.3 Main Class (Multiple Layer Perception)
# In this class, it combines all layers classes and with above classes achieves more than one hidden layers, mini batch, dropout, weight decay, batch normalization, softmax and cross entropy loss, weight normalization, relu, SGD modules.

# %%
class MLP(object):
    def __init__(self, input_layers, hidden_layers, output_layers, activation='relu', weight_norm=False, 
                 dropout=False, keep_prob=0.5, output_softmax_crossEntropyLoss=False, weight_decay=False, weight_lambda=0.01):
        # initialize layers
        self.layers = []
        self.params = []

        self.activation = activation
        self.weight_norm = weight_norm

        self.weight_decay = weight_decay
        self.weight_lambda = weight_lambda

        if self.weight_norm is True:
            print("Using weight normalization")

        # init layers
        # firstly add input layer
        self.layers.append(InputOuput_Layer(
            input_layers, hidden_layers[0], activation=activation, weight_norm=weight_norm
        ))
        # secondly add hidden layers if it more than two
        if len(hidden_layers) >= 2:
            for i in range(len(hidden_layers) - 1):
                self.layers.append(HiddenLayer(
                    hidden_layers[i], hidden_layers[i + 1], activation=activation, weight_norm=weight_norm, \
                    dropout=dropout, keep_prob=keep_prob, weight_decay=self.weight_decay, weight_lambda=self.weight_lambda
                ))
        # finally add output layer
        self.layers.append(InputOuput_Layer(
            hidden_layers[-1], output_layers, activation=activation, weight_norm=weight_norm
        ))

        self.output_softmax_crossEntropyLoss = output_softmax_crossEntropyLoss
        if self.output_softmax_crossEntropyLoss is True:
            print("Using softmax and cross entropy loss in output")

    def forward(self, input, BN, err_BN):
        for layer in self.layers:
            output = layer.forward(input, BN, err_BN)
            input = output
        return output

    def forward_predict(self, input, BN=False, err_BN=1e-8):
        # only use it in predict
        for layer in self.layers:
            output = layer.forward_predict(input, BN, err_BN)
            input = output
        return output

    def criterion_MSE(self, y, y_hat):
        if self.output_softmax_crossEntropyLoss is False:
            activation_deriv = Activation(self.activation).f_deriv
            # MSE
            error = y - y_hat
            loss = error**2
            # write down the delta in the last layer
            delta = -error * activation_deriv(y_hat) / 512
            loss = np.sum(loss)

        # softmax and cross entropy loss
        elif self.output_softmax_crossEntropyLoss is True:
            activation_deriv = Activation(self.activation).f_deriv
            exps = np.exp(y_hat - np.max(y_hat, axis=1, keepdims=True))
            # print(np.max(y_hat, axis=0))
            last_y_out = exps / np.sum(exps, axis=1, keepdims=True)
            error = (last_y_out - y)
            loss = -np.sum(y * np.log(last_y_out), axis=1, keepdims=True)
            # write down the delta in the last layer
            delta = error * activation_deriv(y_hat) / 512
        # return loss and delta
        return loss, delta

    def backward(self, delta):
        for layer in reversed(self.layers):
            delta = layer.backward(delta)

    def backward_BN(self, delta):
        # when implement batch normalization use it not above backward function
        for layer in reversed(self.layers):
            delta = layer.backward_BN(delta)

    def update(self, lr, momentum, gamma_MT):
        # Update without momentum
        if momentum is False:
            for layer in self.layers:
                layer.W -= lr * layer.grad_W
                layer.b -= lr * layer.grad_b
        # Update with momentum
        elif momentum is True:
            for i, layer in enumerate(self.layers):
                layer.v_w = gamma_MT * layer.v_w + lr * layer.grad_W
                layer.W -= layer.v_w
                layer.v_b = gamma_MT * layer.v_b + lr * layer.grad_b
                layer.b -= layer.v_b

    def update_BN(self, lr, momentum, gamma_MT):
        # when implement batch normalization use it not above update function
        # Update without momentum
        if momentum is False:
            for layer in self.layers:
                layer.W -= lr * layer.grad_W
                layer.b -= lr * layer.grad_b
                layer.gamma_BN -= lr * layer.grad_gamma_BN
                layer.beta_BN -= lr * layer.grad_beta_BN

        # Update with momentum
        elif momentum is True:
            for i, layer in enumerate(self.layers):
                layer.v_w = gamma_MT * layer.v_w + lr * layer.grad_W
                layer.W -= layer.v_w
                layer.v_b = gamma_MT * layer.v_b + lr * layer.grad_b
                layer.b -= layer.v_b
                layer.v_gamma_BN = gamma_MT * layer.v_gamma_BN + lr * layer.grad_gamma_BN
                layer.gamma_BN -= layer.v_gamma_BN
                layer.v_beta_BN = gamma_MT * layer.v_beta_BN + lr * layer.grad_beta_BN
                layer.beta_BN -= layer.v_beta_BN

    # mini batch training
    def mini_batches_random(self, X, y, mini_batch_size):
        # the feature at columns
        num_samples = X.shape[0]
        mini_batches = []

        permutation = list(np.random.permutation(num_samples))
        rand_X = X[permutation, :]
        rand_y = y[permutation, :]#.reshape(num_samples, 10)

        num_complete = num_samples // mini_batch_size

        for i in range(num_complete):
            mini_batch_X = rand_X[i * mini_batch_size: (i + 1) * mini_batch_size, :]
            mini_batch_y = rand_y[i * mini_batch_size: (i + 1) * mini_batch_size, :]

            mini_batch = (mini_batch_X, mini_batch_y)
            mini_batches.append(mini_batch)

        if num_samples % mini_batch_size != 0:
            mini_batch_X = rand_X[num_complete * mini_batch_size:, :]
            mini_batch_y = rand_y[num_complete * mini_batch_size:, :]

            mini_batch = (mini_batch_X, mini_batch_y)
            mini_batches.append(mini_batch)
        return mini_batches

    def fit(self, X, y, learning_rate=0.1, epochs=100, gd='mini_batch', 
            momentum=False, gamma_MT=0.9, mini_batch_size=64, batch_norm=False, err_BN=1e-8):
        X = np.array(X)
        y = np.array(y)
        to_return = np.zeros(epochs)
        self.BN = batch_norm
        if self.BN is True:
            print("Using batch normalization")
        self.err_BN = err_BN
        if momentum is True:
            print('Using momentum')

        # Implement Gradient Descent
        if gd == 'GD':
            print("Using GD")
            for k in range(epochs):
                epoch_start_time = time()
                loss = np.zeros(X.shape[0])
                for it in range(X.shape[0]):
                    i = np.random.randint(X.shape[0])
                    # forward pass
                    y_hat = self.forward(X[i], batch_norm, err_BN)
                    # backward pass
                    loss[it], delta = self.criterion_MSE(y[i], y_hat)
                    self.backward(delta)
                    # update
                    self.update(learning_rate, momentum, gamma_MT)
                to_return[k] = np.mean(loss)
                epoch_end_time = time()
                print("---------------------------------------\n--- the epoch %s loss: %4f and used: %2f seconds" 
                          % (str(k+1), to_return[k], (epoch_end_time - epoch_start_time)))

        if gd == 'SGD':
            print("Using SGD")
            for k in range(epochs):
                epoch_start_time = time()
                loss = 0
                i = np.random.randint(X.shape[0])
                # forward pass
                y_hat = self.forward(X[i], batch_norm, err_BN)
                # backward pass
                loss, delta = self.criterion_MSE(y[i], y_hat)
                self.backward(delta)
                # update
                self.update(learning_rate, momentum, gamma_MT)
                to_return[k] = np.mean(loss)
                epoch_end_time = time()
                print("---------------------------------------\n--- the epoch %s loss: %4f and used: %2f seconds" 
                          % (str(k+1), to_return[k], (epoch_end_time - epoch_start_time)))

        # Implement Mini Batch
        if gd == 'mini_batch':
            print("Using mini batch")
            print("the mini batch size is {}".format(mini_batch_size))
            for k in range(epochs):
                epoch_start_time = time()
                loss = np.zeros(X.shape[0])
                # seed = k
                mini_batches = self.mini_batches_random(X, y, mini_batch_size)

                for it, mini_batch in enumerate(mini_batches):
                    loss_it = 0
                    (mini_batch_X, mini_batch_y) = mini_batch
                    # forward pass
                    y_hat = self.forward(mini_batch_X, batch_norm, err_BN)
                    # backward pass
                    loss_it, delta = self.criterion_MSE(mini_batch_y, y_hat)
                    loss[it] = np.mean(loss_it)

                    # judge BN
                    if batch_norm is False:
                        self.backward(delta)
                        # update
                        self.update(learning_rate, momentum, gamma_MT)
                    elif batch_norm is True:
                        self.backward_BN(delta)
                        # update
                        self.update_BN(learning_rate, momentum, gamma_MT)

                to_return[k] = np.mean(loss)
                epoch_end_time = time()
                print("---------------------------------------\n--- the epoch %s loss: %4f and used: %2f seconds" 
                          % (str(k+1), to_return[k], (epoch_end_time - epoch_start_time)))
        # return to_return
        return to_return

    def predict(self, x, model):
        x = np.array(x)
        output = model.forward_predict(x, self.BN, self.err_BN)
        # when implement output softmax, do it
        if self.output_softmax_crossEntropyLoss is True:
            exps_out = np.exp(output)
            output = exps_out / np.sum(exps_out, axis=1, keepdims=True)
        return output

# %% [markdown]
# ### 3.4 Other Functions
# #### 3.4.1 Define calculate accuracy function

# %%
def calculateAcc(testLabel, realLabel):
    acc_num = 0
    for i in range(len(testLabel)):
        if (testLabel[i] == realLabel[i]):
            acc_num += 1
    acc = acc_num / len(realLabel)
    print("\n--- the accuracy is: {:.4%}".format(float(acc)))
    return acc

# %% [markdown]
# #### 3.4.2 Define split data function

# %%
def splitData(inputDat, labelData, precentage=0.8):
    data_training_shape = int(inputDat.shape[0] * precentage)

    data_index = np.random.permutation(inputDat.shape[0])
    data_training_index = data_index[:data_training_shape]
    data_testing_index = data_index[data_training_shape:]

    trainDat = inputDat[data_training_index]
    trainLabel = labelData[data_training_index]

    testDat = inputDat[data_testing_index]
    testLabel = labelData[data_testing_index]
    return trainDat, trainLabel, testDat, testLabel

# %% [markdown]
# #### 3.4.3 Define predict data function

# %%
def predict_data(test_data, model):
    predictLabel = model.predict(test_data, model)
    predict_array = np.array(predictLabel)
    predictLabel = (predict_array == predict_array.max(axis=1, keepdims=1)).astype(float)
    predictLabel = [np.where(r == 1)[0][0] for r in predictLabel]
    return predictLabel

# %% [markdown]
# #### 3.4.4 Define build confusion matrix function

# %%
def build_confusion_matrix(testLabel, realLabel):
    from sklearn.metrics import confusion_matrix
    CM = confusion_matrix(testLabel, realLabel, labels=np.array(range(10)))
    fig, ax = pl.subplots(figsize=(10,8))
    fig.suptitle("Confusion Matrix", fontsize=20)
    heatmap = ax.pcolor(CM, cmap=pl.cm.Blues)

    ax.set_xticks(np.arange(CM.shape[1]) + 0.5, minor=False)
    ax.set_yticks(np.arange(CM.shape[0]) + 0.5, minor=False)
    ax.invert_yaxis()
    ax.xaxis.tick_top()
    fig.colorbar(heatmap)
    ax.set_xticklabels(np.array(range(10)), minor=False)
    ax.set_yticklabels(np.array(range(10)), minor=False)
    pl.show()

# %% [markdown]
# ## 4.Classifier Development, Training and Analysis
# ### 4.1 Classifier Test Preprocessing
# #### 4.1.1 Split train data

# %%
# split data
trainDat, trainLabel, testDat, testLabel = splitData(input_data, label_data, precentage=0.8)
realLabel = [np.where(r == 1)[0][0] for r in testLabel]

# %% [markdown]
# ### 4.2 Classifier Application Test I
# After plenty of experiments, we find two better models as follow:
# #### 4.2.1 Training Relu in mini_batch with dropout, weight decay,  weight normalization, momentum
# While the experiment, we found dropout implement with batch normalization would result in lower accuracy, and if softmax with weight decay also arose same problem.
#
# So based on relu activation function, the hidden layer is 80, 90, 95, with weight normalization, dropout (keep probability is 0.9), weight decay ($\lambda=0.0000004$), momentum ($\gamma=0.8$), learning rate is 0.01, epoch is 60, mini batch (size=512) would be better module.

# %%
start_relu_time = time()

# Try different MLP models
nn_relu = MLP(input_data.shape[1], [80, 90, 95], label_data.shape[1], 'relu', weight_norm=True, dropout=True, \
              keep_prob=0.9, output_softmax_crossEntropyLoss=False, weight_decay=True, weight_lambda=0.0000004)

# Try different fit models
MSE_relu = nn_relu.fit(trainDat, trainLabel, learning_rate=0.01, epochs=60, gd='mini_batch', \
                       momentum=True, gamma_MT=0.8, mini_batch_size=512, batch_norm=False)

print("------------------\n")
print('last loss:%f' % MSE_relu[-1])

end_relu_fit_time = time()
print("--- Relu Fit used: %2f seconds" % (end_relu_fit_time - start_relu_time))

pl.figure(figsize=(15,4))
pl.title('relu function loss in each epoch', fontsize=20) 
pl.plot(MSE_relu, color="navy")
pl.grid()
pl.show()
# Out:
# Using weight normalization
# Using dropout
# Using dropout
# Using momentum
# Using mini batch
# the mini batch size is 512
# ---------------------------------------
# --- the epoch 1 loss: 0.885127 and used: 0.946392 seconds
# ---------------------------------------
# --- the epoch 2 loss: 0.652271 and used: 0.881135 seconds
# ---------------------------------------
# --- the epoch 3 loss: 0.454385 and used: 0.872538 seconds
# ---------------------------------------
# --- the epoch 4 loss: 0.397384 and used: 0.883614 seconds
# ---------------------------------------
# --- the epoch 5 loss: 0.372622 and used: 0.888226 seconds
# ---------------------------------------
# --- the epoch 6 loss: 0.357100 and used: 0.966291 seconds
# ---------------------------------------
# --- the epoch 7 loss: 0.344943 and used: 1.201973 seconds
# ---------------------------------------
# --- the epoch 8 loss: 0.336812 and used: 0.844669 seconds
# ---------------------------------------
# --- the epoch 9 loss: 0.327232 and used: 0.893838 seconds
# ---------------------------------------
# --- the epoch 10 loss: 0.321515 and used: 0.842904 seconds
# ---------------------------------------
# --- the epoch 11 loss: 0.316699 and used: 0.726343 seconds
# ---------------------------------------
# --- the epoch 12 loss: 0.312811 and used: 0.780072 seconds
# ---------------------------------------
# --- the epoch 13 loss: 0.307545 and used: 0.741435 seconds
# ---------------------------------------
# --- the epoch 14 loss: 0.305749 and used: 0.716418 seconds
# ---------------------------------------
# --- the epoch 15 loss: 0.303422 and used: 0.704170 seconds
# ---------------------------------------
# --- the epoch 16 loss: 0.299539 and used: 0.711457 seconds
# ---------------------------------------
# --- the epoch 17 loss: 0.298375 and used: 0.705500 seconds
# ---------------------------------------
# --- the epoch 18 loss: 0.296799 and used: 0.700706 seconds
# ---------------------------------------
# --- the epoch 19 loss: 0.296022 and used: 0.704591 seconds
# ---------------------------------------
# --- the epoch 20 loss: 0.295491 and used: 0.707528 seconds
# ---------------------------------------
# --- the epoch 21 loss: 0.292876 and used: 0.698990 seconds
# ---------------------------------------
# --- the epoch 22 loss: 0.291270 and used: 0.696906 seconds
# ---------------------------------------
# --- the epoch 23 loss: 0.290375 and used: 0.707984 seconds
# ---------------------------------------
# --- the epoch 24 loss: 0.290086 and used: 0.703577 seconds
# ---------------------------------------
# --- the epoch 25 loss: 0.288713 and used: 0.700359 seconds
# ---------------------------------------
# --- the epoch 26 loss: 0.287257 and used: 0.697573 seconds
# ---------------------------------------
# --- the epoch 27 loss: 0.288202 and used: 0.705263 seconds
# ---------------------------------------
# --- the epoch 28 loss: 0.287610 and used: 0.706597 seconds
# ---------------------------------------
# --- the epoch 29 loss: 0.286945 and used: 0.700277 seconds
# ---------------------------------------
# --- the epoch 30 loss: 0.285744 and used: 0.794489 seconds
# ---------------------------------------
# --- the epoch 31 loss: 0.286217 and used: 0.726657 seconds
# ---------------------------------------
# --- the epoch 32 loss: 0.284036 and used: 0.706691 seconds
# ---------------------------------------
# --- the epoch 33 loss: 0.282441 and used: 0.699931 seconds
# ---------------------------------------
# --- the epoch 34 loss: 0.282879 and used: 0.694898 seconds
# ---------------------------------------
# --- the epoch 35 loss: 0.283616 and used: 0.695993 seconds
# ---------------------------------------
# --- the epoch 36 loss: 0.283729 and used: 0.695133 seconds
# ---------------------------------------
# --- the epoch 37 loss: 0.283532 and used: 0.698715 seconds
# ---------------------------------------
# --- the epoch 38 loss: 0.282342 and used: 0.695026 seconds
# ---------------------------------------
# --- the epoch 39 loss: 0.281928 and used: 0.691435 seconds
# ---------------------------------------
# --- the epoch 40 loss: 0.282492 and used: 0.692427 seconds
# ---------------------------------------
# --- the epoch 41 loss: 0.281844 and used: 0.695213 seconds
# ---------------------------------------
# --- the epoch 42 loss: 0.282881 and used: 0.693854 seconds
# ---------------------------------------
# --- the epoch 43 loss: 0.279438 and used: 0.750018 seconds
# ---------------------------------------
# --- the epoch 44 loss: 0.278684 and used: 0.734727 seconds
# ---------------------------------------
# --- the epoch 45 loss: 0.278662 and used: 0.699171 seconds
# ---------------------------------------
# --- the epoch 46 loss: 0.280998 and used: 0.690834 seconds
# ---------------------------------------
# --- the epoch 47 loss: 0.279415 and used: 0.695622 seconds
# ---------------------------------------
# --- the epoch 48 loss: 0.278695 and used: 0.698857 seconds
# ---------------------------------------
# --- the epoch 49 loss: 0.277943 and used: 0.698201 seconds
# ---------------------------------------
# --- the epoch 50 loss: 0.279470 and used: 0.693656 seconds
# ---------------------------------------
# --- the epoch 51 loss: 0.277974 and used: 0.691811 seconds
# ---------------------------------------
# --- the epoch 52 loss: 0.278458 and used: 0.693252 seconds
# ---------------------------------------
# --- the epoch 53 loss: 0.277721 and used: 0.692703 seconds
# ---------------------------------------
# --- the epoch 54 loss: 0.277162 and used: 0.688340 seconds
# ---------------------------------------
# --- the epoch 55 loss: 0.278811 and used: 0.696849 seconds
# ---------------------------------------
# --- the epoch 56 loss: 0.277592 and used: 0.690973 seconds
# ---------------------------------------
# --- the epoch 57 loss: 0.279870 and used: 0.695592 seconds
# ---------------------------------------
# --- the epoch 58 loss: 0.278824 and used: 0.701548 seconds
# ---------------------------------------
# --- the epoch 59 loss: 0.277641 and used: 0.697749 seconds
# ---------------------------------------
# --- the epoch 60 loss: 0.277140 and used: 0.701756 seconds
# ------------------
#
# last loss:0.277140
# --- Relu Fit used: 44.563896 seconds

# %% [markdown]
# #### 4.2.2 Using this test model to predict test data, calculate accuracy, and show confusion matrix

# %%
# Predict splited test data
predictLabel_relu = predict_data(testDat, nn_relu)
acc_relu = calculateAcc(predictLabel_relu, realLabel)
build_confusion_matrix(predictLabel_relu, realLabel)
# Out:
# --- the accuracy is: 84.6583%

# %% [markdown]
# ### 4.3 Classifier Application Test II
# #### 4.3.1 Training tanh in mini batch with batch normalization, softmax, momentum, weight normalization
# While the experiment, we found dropout implement with batch normalization would result in lower accuracy, and if softmax with weight decay also arose same problem.
#
# So based on tanh activation function, the hidden layer is 100, 110, 100, with weight normalization, batch normalization, momentum ($\gamma=0.9$), learning rate is 0.05, mini batch (size=512) would be better module.

# %%
start_tanh_time = time()
# Try different MLP models
nn_tanh = MLP(input_data.shape[1], [100, 110, 100], label_data.shape[1], 'tanh', weight_norm=True, dropout=False, \
              keep_prob=0.8, output_softmax_crossEntropyLoss=True, weight_decay=False, weight_lambda=0.0008)

# Try different fit models
MSE_tanh = nn_tanh.fit(trainDat, trainLabel, learning_rate=0.05, epochs=40, gd='mini_batch', \
                       momentum=True, gamma_MT=0.9, mini_batch_size=512, batch_norm=True)

print("------------------\n")
print('last loss:%f' % MSE_tanh[-1])

end_tanh_fit_time = time()
print("--- Tanh Fit used: %2f seconds" % (end_tanh_fit_time - start_tanh_time))

pl.figure(figsize=(15,4))
pl.title('tanh function cross entropy loss in each epoch', fontsize=20) 
pl.plot(MSE_tanh, color="navy")
pl.grid()
pl.show()
# Out:
# Using weight normalization
# Using softmax and cross entropy loss in output
# Using batch normalization
# Using momentum
# Using mini batch
# the mini batch size is 512
# ---------------------------------------
# --- the epoch 1 loss: 0.003263 and used: 0.821769 seconds
# ---------------------------------------
# --- the epoch 2 loss: 0.002592 and used: 0.823562 seconds
# ---------------------------------------
# --- the epoch 3 loss: 0.002410 and used: 0.802800 seconds
# ---------------------------------------
# --- the epoch 4 loss: 0.002315 and used: 0.801472 seconds
# ---------------------------------------
# --- the epoch 5 loss: 0.002259 and used: 0.878256 seconds
# ---------------------------------------
# --- the epoch 6 loss: 0.002222 and used: 0.791544 seconds
# ---------------------------------------
# --- the epoch 7 loss: 0.002192 and used: 0.775705 seconds
# ---------------------------------------
# --- the epoch 8 loss: 0.002173 and used: 0.866060 seconds
# ---------------------------------------
# --- the epoch 9 loss: 0.002159 and used: 0.908742 seconds
# ---------------------------------------
# --- the epoch 10 loss: 0.002147 and used: 0.803870 seconds
# ---------------------------------------
# --- the epoch 11 loss: 0.002133 and used: 0.834702 seconds
# ---------------------------------------
# --- the epoch 12 loss: 0.002119 and used: 0.894099 seconds
# ---------------------------------------
# --- the epoch 13 loss: 0.002114 and used: 0.790918 seconds
# ---------------------------------------
# --- the epoch 14 loss: 0.002103 and used: 0.843367 seconds
# ---------------------------------------
# --- the epoch 15 loss: 0.002084 and used: 0.788110 seconds
# ---------------------------------------
# --- the epoch 16 loss: 0.002068 and used: 0.777651 seconds
# ---------------------------------------
# --- the epoch 17 loss: 0.002052 and used: 0.782672 seconds
# ---------------------------------------
# --- the epoch 18 loss: 0.002040 and used: 0.775328 seconds
# ---------------------------------------
# --- the epoch 19 loss: 0.002030 and used: 0.780981 seconds
# ---------------------------------------
# --- the epoch 20 loss: 0.002021 and used: 0.830278 seconds
# ---------------------------------------
# --- the epoch 21 loss: 0.002009 and used: 0.812567 seconds
# ---------------------------------------
# --- the epoch 22 loss: 0.001999 and used: 0.849719 seconds
# ---------------------------------------
# --- the epoch 23 loss: 0.001990 and used: 0.791745 seconds
# ---------------------------------------
# --- the epoch 24 loss: 0.001978 and used: 0.789162 seconds
# ---------------------------------------
# --- the epoch 25 loss: 0.001969 and used: 0.918696 seconds
# ---------------------------------------
# --- the epoch 26 loss: 0.001962 and used: 0.798173 seconds
# ---------------------------------------
# --- the epoch 27 loss: 0.001956 and used: 0.781830 seconds
# ---------------------------------------
# --- the epoch 28 loss: 0.001949 and used: 0.777498 seconds
# ---------------------------------------
# --- the epoch 29 loss: 0.001943 and used: 0.792164 seconds
# ---------------------------------------
# --- the epoch 30 loss: 0.001937 and used: 0.785115 seconds
# ---------------------------------------
# --- the epoch 31 loss: 0.001932 and used: 0.843204 seconds
# ---------------------------------------
# --- the epoch 32 loss: 0.001927 and used: 0.881310 seconds
# ---------------------------------------
# --- the epoch 33 loss: 0.001924 and used: 0.836944 seconds
# ---------------------------------------
# --- the epoch 34 loss: 0.001921 and used: 0.846814 seconds
# ---------------------------------------
# --- the epoch 35 loss: 0.001919 and used: 0.828519 seconds
# ---------------------------------------
# --- the epoch 36 loss: 0.001919 and used: 0.962215 seconds
# ---------------------------------------
# --- the epoch 37 loss: 0.001918 and used: 0.908024 seconds
# ---------------------------------------
# --- the epoch 38 loss: 0.001921 and used: 0.871022 seconds
# ---------------------------------------
# --- the epoch 39 loss: 0.001929 and used: 0.859048 seconds
# ---------------------------------------
# --- the epoch 40 loss: 0.001940 and used: 0.812419 seconds
# ------------------
#
# last loss:0.001940
# --- Tanh Fit used: 33.151438 seconds

# %% [markdown]
# #### 4.3.2 Using this test model to predict test data, calculate accuracy, and show confusion matrix

# %%
# Predict splited test data
predictLabel_tanh = predict_data(testDat, nn_tanh)
acc_tanh = calculateAcc(predictLabel_tanh, realLabel)
build_confusion_matrix(predictLabel_tanh, realLabel)
# Out:
# --- the accuracy is: 85.1833%

# %% [markdown]
# ## 5. Using the best model to predict test data

# %% [markdown]
# ### 5.1 Training all of data
#
# we choose the second test model to predict data, but if you want to test the first model predict result, please change 'nn_2' to 'nn_1'.

# %%
start_result_time = time()


def predictResult(nn = 'nn_2'):
    if nn == 'nn_1':
        nn = MLP(input_data.shape[1], [80, 90, 95], label_data.shape[1], 'relu', weight_norm=True, dropout=True, \
                      keep_prob=0.9, output_softmax_crossEntropyLoss=False, weight_decay=True, weight_lambda=0.0000004)
        MSE = nn.fit(input_data, label_data, learning_rate=0.01, epochs=60, gd='mini_batch', \
                               momentum=True, gamma_MT=0.8, mini_batch_size=512, batch_norm=False)
    if nn == 'nn_2':
        nn = MLP(input_data.shape[1], [100, 110, 100], label_data.shape[1], 'tanh', weight_norm=True, dropout=False, \
                      keep_prob=0.8, output_softmax_crossEntropyLoss=True, weight_decay=False, weight_lambda=0.0008)
        MSE = nn.fit(input_data, label_data, learning_rate=0.03, epochs=120, gd='mini_batch', \
                               momentum=True, gamma_MT=0.9, mini_batch_size=512, batch_norm=True)
    return nn, MSE

nn, MSE = predictResult(nn = 'nn_2')


print("------------------\n")
print('last loss:%f' % MSE[-1])

end_result_fit_time = time()
print("--- The model Fit used: %2f seconds" % (end_result_fit_time - start_result_time))

pl.figure(figsize=(15,4))
pl.title('the function loss in each epoch') 
pl.plot(MSE, color="navy")
pl.grid()
pl.show()
# Out:
# Using weight normalization
# Using softmax and cross entropy loss in output
# Using batch normalization
# Using momentum
# Using mini batch
# the mini batch size is 512
# ---------------------------------------
# --- the epoch 1 loss: 0.003317 and used: 1.039525 seconds
# ---------------------------------------
# --- the epoch 2 loss: 0.002633 and used: 1.042523 seconds
# ---------------------------------------
# --- the epoch 3 loss: 0.002444 and used: 1.036706 seconds
# ---------------------------------------
# --- the epoch 4 loss: 0.002342 and used: 1.050757 seconds
# ---------------------------------------
# --- the epoch 5 loss: 0.002279 and used: 1.126548 seconds
# ---------------------------------------
# --- the epoch 6 loss: 0.002235 and used: 1.073179 seconds
# ---------------------------------------
# --- the epoch 7 loss: 0.002203 and used: 1.036188 seconds
# ---------------------------------------
# --- the epoch 8 loss: 0.002178 and used: 1.039889 seconds
# ---------------------------------------
# --- the epoch 9 loss: 0.002162 and used: 1.051638 seconds
# ---------------------------------------
# --- the epoch 10 loss: 0.002145 and used: 1.040103 seconds
# ---------------------------------------
# --- the epoch 11 loss: 0.002134 and used: 1.050923 seconds
# ---------------------------------------
# --- the epoch 12 loss: 0.002126 and used: 1.156657 seconds
# ---------------------------------------
# --- the epoch 13 loss: 0.002116 and used: 1.110123 seconds
# ---------------------------------------
# --- the epoch 14 loss: 0.002110 and used: 1.049541 seconds
# ---------------------------------------
# --- the epoch 15 loss: 0.002103 and used: 1.011462 seconds
# ---------------------------------------
# --- the epoch 16 loss: 0.002099 and used: 1.081296 seconds
# ---------------------------------------
# --- the epoch 17 loss: 0.002092 and used: 1.175806 seconds
# ---------------------------------------
# --- the epoch 18 loss: 0.002087 and used: 1.114697 seconds
# ---------------------------------------
# --- the epoch 19 loss: 0.002082 and used: 1.219348 seconds
# ---------------------------------------
# --- the epoch 20 loss: 0.002075 and used: 1.086747 seconds
# ---------------------------------------
# --- the epoch 21 loss: 0.002069 and used: 1.030180 seconds
# ---------------------------------------
# --- the epoch 22 loss: 0.002067 and used: 0.984887 seconds
# ---------------------------------------
# --- the epoch 23 loss: 0.002059 and used: 0.983868 seconds
# ---------------------------------------
# --- the epoch 24 loss: 0.002057 and used: 0.979518 seconds
# ---------------------------------------
# --- the epoch 25 loss: 0.002053 and used: 0.986492 seconds
# ---------------------------------------
# --- the epoch 26 loss: 0.002048 and used: 0.978927 seconds
# ---------------------------------------
# --- the epoch 27 loss: 0.002045 and used: 1.037911 seconds
# ---------------------------------------
# --- the epoch 28 loss: 0.002042 and used: 1.018059 seconds
# ---------------------------------------
# --- the epoch 29 loss: 0.002038 and used: 1.006612 seconds
# ---------------------------------------
# --- the epoch 30 loss: 0.002034 and used: 1.254025 seconds
# ---------------------------------------
# --- the epoch 31 loss: 0.002029 and used: 1.053689 seconds
# ---------------------------------------
# --- the epoch 32 loss: 0.002025 and used: 1.019745 seconds
# ---------------------------------------
# --- the epoch 33 loss: 0.002021 and used: 1.000358 seconds
# ---------------------------------------
# --- the epoch 34 loss: 0.002021 and used: 1.043556 seconds
# ---------------------------------------
# --- the epoch 35 loss: 0.002017 and used: 1.167114 seconds
# ---------------------------------------
# --- the epoch 36 loss: 0.002012 and used: 1.145109 seconds
# ---------------------------------------
# --- the epoch 37 loss: 0.002008 and used: 1.148388 seconds
# ---------------------------------------
# --- the epoch 38 loss: 0.002006 and used: 1.079978 seconds
# ---------------------------------------
# --- the epoch 39 loss: 0.002001 and used: 1.044986 seconds
# ---------------------------------------
# --- the epoch 40 loss: 0.001996 and used: 0.994220 seconds
# ---------------------------------------
# --- the epoch 41 loss: 0.001991 and used: 0.979736 seconds
# ---------------------------------------
# --- the epoch 42 loss: 0.001987 and used: 0.980021 seconds
# ---------------------------------------
# --- the epoch 43 loss: 0.001981 and used: 0.965310 seconds
# ---------------------------------------
# --- the epoch 44 loss: 0.001979 and used: 1.019342 seconds
# ---------------------------------------
# --- the epoch 45 loss: 0.001976 and used: 1.352794 seconds
# ---------------------------------------
# --- the epoch 46 loss: 0.001970 and used: 1.145191 seconds
# ---------------------------------------
# --- the epoch 47 loss: 0.001968 and used: 1.203759 seconds
# ---------------------------------------
# --- the epoch 48 loss: 0.001963 and used: 1.227473 seconds
# ---------------------------------------
# --- the epoch 49 loss: 0.001960 and used: 1.197239 seconds
# ---------------------------------------
# --- the epoch 50 loss: 0.001956 and used: 1.226819 seconds
# ---------------------------------------
# --- the epoch 51 loss: 0.001952 and used: 1.578406 seconds
# ---------------------------------------
# --- the epoch 52 loss: 0.001950 and used: 1.361805 seconds
# ---------------------------------------
# --- the epoch 53 loss: 0.001945 and used: 1.106813 seconds
# ---------------------------------------
# --- the epoch 54 loss: 0.001942 and used: 1.122295 seconds
# ---------------------------------------
# --- the epoch 55 loss: 0.001939 and used: 1.124380 seconds
# ---------------------------------------
# --- the epoch 56 loss: 0.001935 and used: 1.055062 seconds
# ---------------------------------------
# --- the epoch 57 loss: 0.001933 and used: 0.978182 seconds
# ---------------------------------------
# --- the epoch 58 loss: 0.001930 and used: 1.051304 seconds
# ---------------------------------------
# --- the epoch 59 loss: 0.001926 and used: 1.100480 seconds
# ---------------------------------------
# --- the epoch 60 loss: 0.001925 and used: 0.969062 seconds
# ---------------------------------------
# --- the epoch 61 loss: 0.001922 and used: 0.982838 seconds
# ---------------------------------------
# --- the epoch 62 loss: 0.001919 and used: 1.138758 seconds
# ---------------------------------------
# --- the epoch 63 loss: 0.001918 and used: 0.982147 seconds
# ---------------------------------------
# --- the epoch 64 loss: 0.001916 and used: 0.992094 seconds
# ---------------------------------------
# --- the epoch 65 loss: 0.001915 and used: 1.197820 seconds
# ---------------------------------------
# --- the epoch 66 loss: 0.001915 and used: 1.102220 seconds
# ---------------------------------------
# --- the epoch 67 loss: 0.001911 and used: 1.039436 seconds
# ---------------------------------------
# --- the epoch 68 loss: 0.001911 and used: 1.170323 seconds
# ---------------------------------------
# --- the epoch 69 loss: 0.001909 and used: 1.107297 seconds
# ---------------------------------------
# --- the epoch 70 loss: 0.001907 and used: 1.000832 seconds
# ---------------------------------------
# --- the epoch 71 loss: 0.001904 and used: 0.980157 seconds
# ---------------------------------------
# --- the epoch 72 loss: 0.001905 and used: 1.033178 seconds
# ---------------------------------------
# --- the epoch 73 loss: 0.001903 and used: 0.985244 seconds
# ---------------------------------------
# --- the epoch 74 loss: 0.001900 and used: 0.994812 seconds
# ---------------------------------------
# --- the epoch 75 loss: 0.001900 and used: 1.049725 seconds
# ---------------------------------------
# --- the epoch 76 loss: 0.001899 and used: 0.988909 seconds
# ---------------------------------------
# --- the epoch 77 loss: 0.001897 and used: 0.975571 seconds
# ---------------------------------------
# --- the epoch 78 loss: 0.001896 and used: 0.988532 seconds
# ---------------------------------------
# --- the epoch 79 loss: 0.001896 and used: 1.003288 seconds
# ---------------------------------------
# --- the epoch 80 loss: 0.001894 and used: 1.081696 seconds
# ---------------------------------------
# --- the epoch 81 loss: 0.001894 and used: 0.999749 seconds
# ---------------------------------------
# --- the epoch 82 loss: 0.001894 and used: 0.991350 seconds
# ---------------------------------------
# --- the epoch 83 loss: 0.001893 and used: 0.975869 seconds
# ---------------------------------------
# --- the epoch 84 loss: 0.001892 and used: 0.981282 seconds
# ---------------------------------------
# --- the epoch 85 loss: 0.001892 and used: 0.999436 seconds
# ---------------------------------------
# --- the epoch 86 loss: 0.001890 and used: 0.992115 seconds
# ---------------------------------------
# --- the epoch 87 loss: 0.001890 and used: 0.979703 seconds
# ---------------------------------------
# --- the epoch 88 loss: 0.001891 and used: 0.979437 seconds
# ---------------------------------------
# --- the epoch 89 loss: 0.001889 and used: 0.979976 seconds
# ---------------------------------------
# --- the epoch 90 loss: 0.001890 and used: 0.983849 seconds
# ---------------------------------------
# --- the epoch 91 loss: 0.001889 and used: 1.068668 seconds
# ---------------------------------------
# --- the epoch 92 loss: 0.001888 and used: 0.998143 seconds
# ---------------------------------------
# --- the epoch 93 loss: 0.001888 and used: 0.979990 seconds
# ---------------------------------------
# --- the epoch 94 loss: 0.001887 and used: 0.983879 seconds
# ---------------------------------------
# --- the epoch 95 loss: 0.001886 and used: 0.976765 seconds
# ---------------------------------------
# --- the epoch 96 loss: 0.001887 and used: 0.980392 seconds
# ---------------------------------------
# --- the epoch 97 loss: 0.001886 and used: 1.028727 seconds
# ---------------------------------------
# --- the epoch 98 loss: 0.001885 and used: 1.100434 seconds
# ---------------------------------------
# --- the epoch 99 loss: 0.001885 and used: 1.237770 seconds
# ---------------------------------------
# --- the epoch 100 loss: 0.001884 and used: 1.005890 seconds
# ---------------------------------------
# --- the epoch 101 loss: 0.001883 and used: 1.107918 seconds
# ---------------------------------------
# --- the epoch 102 loss: 0.001883 and used: 1.163428 seconds
# ---------------------------------------
# --- the epoch 103 loss: 0.001882 and used: 1.065394 seconds
# ---------------------------------------
# --- the epoch 104 loss: 0.001882 and used: 1.422194 seconds
# ---------------------------------------
# --- the epoch 105 loss: 0.001883 and used: 1.634103 seconds
# ---------------------------------------
# --- the epoch 106 loss: 0.001881 and used: 1.223030 seconds
# ---------------------------------------
# --- the epoch 107 loss: 0.001881 and used: 1.459209 seconds
# ---------------------------------------
# --- the epoch 108 loss: 0.001882 and used: 2.815796 seconds
# ---------------------------------------
# --- the epoch 109 loss: 0.001881 and used: 1.539689 seconds
# ---------------------------------------
# --- the epoch 110 loss: 0.001880 and used: 1.972583 seconds
# ---------------------------------------
# --- the epoch 111 loss: 0.001881 and used: 2.670084 seconds
# ---------------------------------------
# --- the epoch 112 loss: 0.001879 and used: 1.943798 seconds
# ---------------------------------------
# --- the epoch 113 loss: 0.001878 and used: 1.863896 seconds
# ---------------------------------------
# --- the epoch 114 loss: 0.001878 and used: 2.226093 seconds
# ---------------------------------------
# --- the epoch 115 loss: 0.001877 and used: 2.851126 seconds
# ---------------------------------------
# --- the epoch 116 loss: 0.001875 and used: 3.020028 seconds
# ---------------------------------------
# --- the epoch 117 loss: 0.001876 and used: 3.200495 seconds
# ---------------------------------------
# --- the epoch 118 loss: 0.001875 and used: 1.766357 seconds
# ---------------------------------------
# --- the epoch 119 loss: 0.001875 and used: 2.090631 seconds
# ---------------------------------------
# --- the epoch 120 loss: 0.001873 and used: 2.426262 seconds
# ------------------
#
# last loss:0.001873
# --- The model Fit used: 145.863575 seconds

# %% [markdown]
# ### 5.2 Predict the test data and save to csv file

# %%
start_predict_time = time()

predictLabel = predict_data(test_data, nn)

end_predict_time = time()
print("--- The model predict used: %2f seconds" % (end_predict_time - start_predict_time))
print("--- The model total used: %2f seconds" % (end_predict_time - start_result_time))

output_data = pd.DataFrame(predictLabel)
output_data.to_csv("Predicted_labels.h5", sep=",", index = False, header=False)
# Out:
# --- The model predict used: 0.479873 seconds
# --- The model total used: 147.087727 seconds
